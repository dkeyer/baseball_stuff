# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup
from __future__ import print_function
import statsapi

from datetime import date
import datetime
#imports

# %%
url = 'https://baseballsavant.mlb.com/leaderboard/expected_statistics?type=batter&year=2022&position=&team=&min=q&sort=1&sortDir=desc'

# %%
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')
#Making request to the site and storing it in soup

# %%
stuff = soup.find('body', id ='leaderboard_expected')

# %%
stuff
# Out:
# <body class="lang-en_US" id="leaderboard_expected">
# <!-- header-->
# <header id="header-nav">
# <div class="header-top">
# <div id="header-bar">
# <div>
# <a href="/"><img class="mlb-logo" src="/site-core/images/savant-logo.svg"/></a>
# </div>
# <div class="logo-text">
# <div class="logo">
# <a href="/"><span class="primary-color">savant</span></a>
# </div>
# </div>
# </div>
# </div>
# <div class="wrap">
# <nav class="nav">
# <div class="temp" id="hamburger">
# <div class="ham1"></div>
# <div class="ham2"></div>
# <div class="ham3"></div>
# </div>
# <ul class="nav-menu">
# <li class="item">
# <a href="https://mlb.com"><img src="/site-core/images/savant-mlb.svg" style="width: 50px"/></a>
# </li>
# <li class="item"><a href="/illustrator">illustrator</a></li>
# <li class="item"><a href="/gamefeed">Gamefeed</a></li>
# <li class="item"><a href="/scoreboard">Scoreboard</a></li>
# <li class="item">
# <a href="/probable-pitchers">Probable Pitchers</a>
# </li>
# <li class="item"><a href="/statcast_search">Search</a></li>
# <li class="item"><a href="/visuals">Visuals</a></li>
# <li class="item">
# <div class="leaderboards">
# <a href="#">Statistics</a>
# <div class="lbbox box sbox">
# <div class="title" style="margin-bottom: 0rem !important">
#                                 Statcast Statistics
#                             </div>
# <div class="stats-menu">
# <div>
# <ul>
# <li class="menu title-leaderboard">
#                                             Player Batting
#                                         </li>
# <li style="font-size: 0.9rem">
# <a href="/leaderboard/custom?year=2022&amp;filter=&amp;sort=4&amp;sortDir=desc&amp;min=q&amp;selections=xba,xslg,xwoba,xobp,xiso,exit_velocity_avg,launch_angle_avg,barrel_batted_rate,&amp;chart=false&amp;x=xba&amp;y=xba&amp;r=no&amp;chartType=beeswarm">
#                                                 2022
#                                             </a>
#                                             |
#                                             <a href="/leaderboard/custom?year=2021&amp;filter=&amp;sort=4&amp;sortDir=desc&amp;min=q&amp;selections=xba,xslg,xwoba,xobp,xiso,exit_velocity_avg,launch_angle_avg,barrel_batted_rate,&amp;chart=false&amp;x=xba&amp;y=xba&amp;r=no&amp;chartType=beeswarm">
#                                                 2021
#                                             </a>
#                                             |
#                                             <a href="/leaderboard/custom?year=2020&amp;filter=&amp;sort=4&amp;sortDir=desc&amp;min=q&amp;selections=xba,xslg,xwoba,xobp,xiso,exit_velocity_avg,launch_angle_avg,barrel_batted_rate,&amp;chart=false&amp;x=xba&amp;y=xba&amp;r=no&amp;chartType=beeswarm">
#                                                 2020
#                                             </a>
#                                             |
#                                             <a href="/leaderboard/custom?year=2019&amp;filter=&amp;sort=4&amp;sortDir=desc&amp;min=q&amp;selections=xba,xslg,xwoba,xobp,xiso,exit_velocity_avg,launch_angle_avg,barrel_batted_rate,&amp;chart=false&amp;x=xba&amp;y=xba&amp;r=no&amp;chartType=beeswarm">
#                                                 2019
#                                             </a>
#                                             |
#                                             <a href="/leaderboard/custom?year=2018&amp;filter=&amp;sort=4&amp;sortDir=desc&amp;min=q&amp;selections=xba,xslg,xwoba,xobp,xiso,exit_velocity_avg,launch_angle_avg,barrel_batted_rate,&amp;chart=false&amp;x=xba&amp;y=xba&amp;r=no&amp;chartType=beeswarm">
#                                                 2018
#                                             </a>
#                                             |
#                                             <a href="/leaderboard/custom?year=2017&amp;filter=&amp;sort=4&amp;sortDir=desc&amp;min=q&amp;selections=xba,xslg,xwoba,xobp,xiso,exit_velocity_avg,launch_angle_avg,barrel_batted_rate,&amp;chart=false&amp;x=xba&amp;y=xba&amp;r=no&amp;chartType=beeswarm">
#                                                 2017
#                                             </a>
#                                             |
#                                             <a href="/leaderboard/custom?year=2022,2021,2020,2019,2018,2017,2016,2015&amp;filter=&amp;sort=4&amp;sortDir=desc&amp;min=q&amp;selections=xba,xslg,xwoba,xobp,xiso,exit_velocity_avg,launch_angle_avg,barrel_batted_rate,&amp;chart=false&amp;x=xba&amp;y=xba&amp;r=no&amp;chartType=beeswarm">
#                                                 All
#                                             </a>
# </li>
# <li class="menu title-leaderboard">
#                                             Player Pitching
#                                         </li>
# <li style="font-size: 0.9rem">
# <a href="/leaderboard/custom?year=2022&amp;type=pitcher&amp;filter=&amp;sort=4&amp;sortDir=asc&amp;min=q&amp;selections=xba,xslg,xwoba,xobp,xiso,exit_velocity_avg,launch_angle_avg,barrel_batted_rate,&amp;chart=false&amp;x=xba&amp;y=xba&amp;r=no&amp;chartType=beeswarm">
#                                                 2022
#                                             </a>
#                                             |
#                                             <a href="/leaderboard/custom?year=2021&amp;type=pitcher&amp;filter=&amp;sort=4&amp;sortDir=asc&amp;min=q&amp;selections=xba,xslg,xwoba,xobp,xiso,exit_velocity_avg,launch_angle_avg,barrel_batted_rate,&amp;chart=false&amp;x=xba&amp;y=xba&amp;r=no&amp;chartType=beeswarm">
#                                                 2021
#                                             </a>
#                                             |
#                                             <a href="/leaderboard/custom?year=2020&amp;type=pitcher&amp;filter=&amp;sort=4&amp;sortDir=asc&amp;min=q&amp;selections=xba,xslg,xwoba,xobp,xiso,exit_velocity_avg,launch_angle_avg,barrel_batted_rate,&amp;chart=false&amp;x=xba&amp;y=xba&amp;r=no&amp;chartType=beeswarm">
#                                                 2020
#                                             </a>
#                                             |
#                                             <a href="/leaderboard/custom?year=2019&amp;type=pitcher&amp;filter=&amp;sort=4&amp;sortDir=asc&amp;min=q&amp;selections=xba,xslg,xwoba,xobp,xiso,exit_velocity_avg,launch_angle_avg,barrel_batted_rate,&amp;chart=false&amp;x=xba&amp;y=xba&amp;r=no&amp;chartType=beeswarm">
#                                                 2019
#                                             </a>
#                                             |
#                                             <a href="/leaderboard/custom?year=2018&amp;type=pitcher&amp;filter=&amp;sort=4&amp;sortDir=asc&amp;min=q&amp;selections=xba,xslg,xwoba,xobp,xiso,exit_velocity_avg,launch_angle_avg,barrel_batted_rate,&amp;chart=false&amp;x=xba&amp;y=xba&amp;r=no&amp;chartType=beeswarm">
#                                                 2018
#                                             </a>
#                                             |
#                                             <a href="/leaderboard/custom?year=2017&amp;type=pitcher&amp;filter=&amp;sort=4&amp;sortDir=asc&amp;min=q&amp;selections=xba,xslg,xwoba,xobp,xiso,exit_velocity_avg,launch_angle_avg,barrel_batted_rate,&amp;chart=false&amp;x=xba&amp;y=xba&amp;r=no&amp;chartType=beeswarm">
#                                                 2017
#                                             </a>
#                                             |
#                                             <a href="/leaderboard/custom?year=2022,2021,2020,2019,2018,2017,2016,2015&amp;type=pitcher&amp;filter=&amp;sort=4&amp;sortDir=asc&amp;min=q&amp;selections=xba,xslg,xwoba,xobp,xiso,exit_velocity_avg,launch_angle_avg,barrel_batted_rate,&amp;chart=false&amp;x=xba&amp;y=xba&amp;r=no&amp;chartType=beeswarm">
#                                                 All
#                                             </a>
# </li>
# <li class="menu title-leaderboard">
#                                             League Batting
#                                         </li>
# <li style="font-size: 0.9rem">
# <a href="/league?season=2022#statcastHitting">
#                                                 2022
#                                             </a>
#                                             |
#                                             <a href="/league?season=2021#statcastHitting">
#                                                 2021
#                                             </a>
#                                             |
#                                             <a href="/league?season=2020#statcastHitting">
#                                                 2020
#                                             </a>
#                                             |
#                                             <a href="/league?season=2019#statcastHitting">
#                                                 2019
#                                             </a>
#                                             |
#                                             <a href="/league?season=2018#statcastHitting">
#                                                 2018
#                                             </a>
#                                             |
#                                             <a href="/league?season=2017#statcastHitting">
#                                                 2017
#                                             </a>
# </li>
# <li class="menu title-leaderboard">
#                                             League Pitching
#                                         </li>
# <li style="font-size: 0.9rem">
# <a href="/league?view=statcast&amp;nav=pitching&amp;season=2022#statcastPitching">
#                                                 2022
#                                             </a>
#                                             |
#                                             <a href="/league?view=statcast&amp;nav=pitching&amp;season=2021#statcastPitching">
#                                                 2021
#                                             </a>
#                                             |
#                                             <a href="/league?view=statcast&amp;nav=pitching&amp;season=2020#statcastPitching">
#                                                 2020
#                                             </a>
#                                             |
#                                             <a href="/league?view=statcast&amp;nav=pitching&amp;season=2019#statcastPitching">
#                                                 2019
#                                             </a>
#                                             |
#                                             <a href="/league?view=statcast&amp;nav=pitching&amp;season=2018#statcastPitching">
#                                                 2018
#                                             </a>
#                                             |
#                                             <a href="/league?view=statcast&amp;nav=pitching&amp;season=2017#statcastPitching">
#                                                 2017
#                                             </a>
# </li>
# <li></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="item">
# <div class="leaderboards">
# <a href="/leaderboard/statcast">Leaderboards</a>
# <div class="lbbox box">
# <div class="title" style="margin-bottom: 0rem !important">
#                                 Leaderboards
#                             </div>
# <div class="leaderboard-menu">
# <div>
# <ul>
# <li class="menu title-leaderboard">
#                                             Batting
#                                         </li>
# <li>
# <a href="/leaderboard/statcast">Exit Velocity &amp; Barrels</a>
# </li>
# <li>
# <a href="/leaderboard/expected_statistics">Expected Statistics</a>
# </li>
# <li>
# <a href="/leaderboard/rolling">Rolling Windows</a>
# </li>
# <li>
# <a href="/leaderboard/percentile-rankings?type=batter&amp;team=">Percentile Rankings</a>
# </li>
# <li>
# <a href="/leaderboard/swing-take?year=2022">Swing/Take</a>
# </li>
# <li>
# <a href="/leaderboard/pitch-arsenal-stats?type=batter">Pitch Arsenal Stats</a>
# </li>
# <li>
# <a href="/leaderboard/home-runs">Home Runs</a>
# </li>
# <li>
# <a href="/leaderboard/statcast-year-to-year">Year to Year Changes</a>
# </li>
# <li>
# <a href="/leaderboard/pitch-tempo?type=Bat">
#                                                 Pitch Tempo
#                                             </a>
# </li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
# </div>
# <div>
# <ul>
# <li class="menu title-leaderboard">
#                                             Pitching
#                                         </li>
# <li>
# <a href="/leaderboard/statcast?type=pitcher">
#                                                 Exit Velocity &amp; Barrels
#                                             </a>
# </li>
# <li>
# <a href="/leaderboard/expected_statistics?type=pitcher">
#                                                 Expected Statistics
#                                             </a>
# </li>
# <li>
# <a href="/leaderboard/pitch-arsenals">
#                                                 Pitch Arsenals
#                                             </a>
# </li>
# <li>
# <a href="/leaderboard/pitch-arsenal-stats">
#                                                 Pitch Arsenal Stats
#                                             </a>
# </li>
# <li>
# <a href="/leaderboard/pitch-movement">
#                                                 Pitch Movement
#                                             </a>
# </li>
# <li>
# <a href="/leaderboard/active-spin">
#                                                 Active Spin
#                                             </a>
# </li>
# <li>
# <a href="/leaderboard/percentile-rankings?type=pitcher&amp;team=">
#                                                 Percentile Rankings
#                                             </a>
# </li>
# <li>
# <a href="/leaderboard/swing-take?year=2022&amp;team=&amp;group=Pitcher&amp;type=All&amp;sub_type=null&amp;min=q">
#                                                 Swing/Take
#                                             </a>
# </li>
# <li>
# <a href="/leaderboard/home-runs?player_type=Pitcher">
#                                                 Home Runs
#                                             </a>
# </li>
# <li>
# <a href="/leaderboard/statcast-year-to-year?group=Pitcher">
#                                                 Year to Year Changes
#                                             </a>
# </li>
# <li>
# <a href="/leaderboard/pitch-tempo">
#                                                 Pitch Tempo
#                                             </a>
# </li>
# <li>
# <a href="/leaderboard/spin-direction-pitches">
#                                                 Spin Direction
#                                             </a>
# </li>
# <li></li>
# </ul>
# </div>
# <div>
# <ul>
# <li class="menu title-leaderboard">
#                                             Fielding
#                                         </li>
# <li>
# <a href="/leaderboard/outs_above_average">
#                                                 Outs Above Average
#                                             </a>
# </li>
# <li>
# <a href="/leaderboard/outfield_directional_outs_above_average">
#                                                 Outfield Directional OAA
#                                             </a>
# </li>
# <li>
# <a href="/leaderboard/outfield_jump">
#                                                 Outfield Jump
#                                             </a>
# </li>
# <li>
# <a href="/leaderboard/catch_probability">
#                                                 Outfield Catch Probability
#                                             </a>
# </li>
# <li>
# <a href="/leaderboard/poptime">
#                                                 Catcher Poptime
#                                             </a>
# </li>
# <li>
# <a href="/leaderboard/catcher_framing">
#                                                 Catcher Framing
#                                             </a>
# </li>
# <li class="menu title-leaderboard">
#                                             Running
#                                         </li>
# <li>
# <a href="/leaderboard/sprint_speed">
#                                                 Sprint Speed
#                                             </a>
# </li>
# <li>
# <a href="/leaderboard/running_splits">
#                                                 90ft Splits</a>
# </li>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
# </div>
# <div>
# <ul>
# <li class="menu title-leaderboard">
#                                             Fielder Positioning
#                                         </li>
# <li>
# <a href="/visuals/fielder-positioning">Fielder - Situational
#                                             </a>
# </li>
# <li>
# <a href="/visuals/fielder-positioning-all">
#                                                 Fielder - All
#                                             </a>
# </li>
# <li>
# <a href="/visuals/team-positioning">
#                                                 Team Positioning
#                                             </a>
# </li>
# <li>
# <a href="/visuals/batter-positioning">
#                                                 Batter Positioning
#                                             </a>
# </li>
# <li>
# <a href="/visuals/pitcher-positioning">
#                                                 Pitcher Positioning
#                                             </a>
# </li>
# <li class="menu title-leaderboard">
# <a href="/leaderboard/custom?type=batter&amp;filter=&amp;sort=4&amp;sortDir=desc&amp;min=q&amp;selections=xba,xslg,xwoba,xobp,xiso,exit_velocity_avg,launch_angle_avg,barrel_batted_rate,&amp;chart=false&amp;x=xba&amp;y=xba&amp;r=no&amp;chartType=beeswarm" style="color: #b00 !important">
#                                                 Custom Leaderboard
#                                             </a>
# </li>
# <li class="menu title-leaderboard">
# <a href="/leaderboard/top-performers" style="color: #b00 !important">
#                                                 Top Performers
#                                             </a>
# </li>
# <li class="menu title-leaderboard">
# <a href="/leaderboard/statcast-park-factors" style="color: #b00 !important">
#                                                 Statcast Park Factors
#                                             </a>
# </li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="item">
# <div class="gridnav">
# <svg height="18px" id="icon-grid" viewbox="0 0 1000 1000" width="18px" xmlns="http://www.w3.org/2000/svg">
# <path d="M6.4 48.5C6.4 25.1 25.5 6 48.8 6h168.9c23.4 0 42.5 19.1 42.5 42.5v168.9c0 23.4-19.1 42.5-42.5 42.5H48.8c-23.4 0-42.5-19.1-42.5-42.5V48.5h.1zm366.5 0C372.9 25.1 392 6 415.4 6h168.9c23.4 0 42.5 19.1 42.5 42.5v168.9c0 23.4-19.1 42.5-42.5 42.5H415.4c-23.4 0-42.5-19.1-42.5-42.5V48.5zm367.5 0c0-23.4 19.1-42.5 42.5-42.5h168.9c23.4 0 42.5 19.1 42.5 42.5v168.9c0 23.4-19.1 42.5-42.5 42.5H782.9c-23.4 0-42.5-19.1-42.5-42.5V48.5zm0 366.9c0-23.4 19.1-42.5 42.5-42.5h168.9c23.4 0 42.5 19.1 42.5 42.5v168.9c0 23.4-19.1 42.5-42.5 42.5H782.9c-23.4 0-42.5-19.1-42.5-42.5V415.4zm-366.9 0c0-23.4 19.1-42.5 42.5-42.5h168.9c23.4 0 42.5 19.1 42.5 42.5v168.9c0 23.4-19.1 42.5-42.5 42.5H416c-23.4 0-42.5-19.1-42.5-42.5V415.4zm-366.4 0c0-23.4 19.1-42.5 42.5-42.5h168.9c23.4 0 42.5 19.1 42.5 42.5v168.9c0 23.4-19.1 42.5-42.5 42.5H49.6c-23.4 0-42.5-19.1-42.5-42.5V415.4zm-.7 367.3c0-23.4 19.1-42.5 42.5-42.5h168.9c23.4 0 42.5 19.1 42.5 42.5v168.9c0 23.4-19.1 42.5-42.5 42.5h-169c-23.4 0-42.5-19.1-42.5-42.5V782.7h.1zm734 0c0-23.4 19.1-42.5 42.5-42.5h168.9c23.4 0 42.5 19.1 42.5 42.5v168.9c0 23.4-19.1 42.5-42.5 42.5H782.9c-23.4 0-42.5-19.1-42.5-42.5V782.7zm-366.9 0c0-23.4 19.1-42.5 42.5-42.5h168.9c23.4 0 42.5 19.1 42.5 42.5v168.9c0 23.4-19.1 42.5-42.5 42.5H416c-23.4 0-42.5-19.1-42.5-42.5V782.7z"></path>
# </svg>
# <div class="applications box">
# <div style="text-align: left">
# <div class="title">Applications</div>
# <div class="app-menu">
# <div class="menu">
# <a href="/player-comparison">
#                                             Player Comparison Tool
#                                         </a>
# </div>
# <div class="menu">
# <a href="/player-scroll">
#                                             Pitcher Visualization Report
#                                         </a>
# </div>
# <div class="menu">
# <a href="/pitchmix">
#                                             Pitcher Arsenals
#                                         </a>
# </div>
# <div class="menu">
# <a href="/sprint-speed-scroller">
#                                             Sprint Speed Scroller
#                                         </a>
# </div>
# <div class="menu">
# <a href="/visuals/fielder-positioning">
#                                             Player Positioning
#                                         </a>
# </div>
# <div class="menu">
# <a href="/league">
#                                             League Statcast Stats
#                                         </a>
# </div>
# <div class="menu">
# <a href="/visuals/pitch3d">
#                                             3D Pitch Visualizations
#                                         </a>
# </div>
# <div class="menu">
# <a href="/visuals"> Visuals </a>
# </div>
# <div class="menu">
# <a href="/statcast_hit_probability">
#                                             Hit Probability Breakdown
#                                         </a>
# </div>
# <div class="menu">
# <a href="/statcast_catch_probability">
#                                             Catch Probability Breakdown
#                                         </a>
# </div>
# <div class="menu">
# <a href="/statcast_field">Statcast Field Visualizer
#                                         </a>
# </div>
# <div class="menu">
# <a href="/replay">
#                                             Instant Replay Database
#                                         </a>
# </div>
# <div class="menu">
# <a href="/hr_derby"> HR Derby </a>
# </div>
# <div class="menu">
# <a href="/draft"> Draft Tracker </a>
# </div>
# <div class="menu">
# <a href="/games"> Savant Games </a>
# </div>
# <div class="menu">
# <a href="/affinity-pitchersAndHitters-byHittingProfile">
#                                             Player Similarity Scores
#                                         </a>
# </div>
# <div class="menu">
# <a href="/leaderboard/weighted-score">
#                                             Enhanced Game Scores
#                                         </a>
# </div>
# <div class="menu">
# <a href="/drag-dashboard">
#                                             Drag Dashboard
#                                         </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="users">
# <div class="person">
# <svg height="18px" id="icon-login" viewbox="0 0 512 512" width="18px" xmlns="http://www.w3.org/2000/svg">
# <path d="M509 508s0-34.8-2.9-53c-2.4-14.4-22.3-33.3-106.9-64.4-83.3-30.6-78.1-15.7-78.1-71.9 0-36.5 18.6-15.3 30.4-84.6 4.6-27.3 8.3-9.1 18.3-52.8 5.3-22.9-3.6-24.6-2.5-35.6s2.1-20.7 4.1-43.1C373.8 74.9 348.1 2 256 2S138.2 74.9 140.7 102.7c2 22.3 3 32.2 4.1 43.1 1.1 10.9-7.8 12.7-2.5 35.6 10 43.6 13.7 25.4 18.3 52.8 11.9 69.3 30.4 48.1 30.4 84.6 0 56.4 5.1 41.5-78.1 71.9C28.3 421.7 8.3 440.8 6 455.2c-3 18-3 52.8-3 52.8h506z"></path>
# </svg>
# <div class="applications box"></div>
# <div class="applications box">
# <div style="text-align: left">
# <div class="title">
#                                         Saved Statcast Searches
#                                     </div>
# <div class="app-menu" id="navSavedSearches" style="padding-bottom: 1.8rem">
# <!--<div class="menu">
#           <a href="#">Home Run Exit Velocity</a>
#         </div>
#         <div class="menu">
#           <a href="#">Fastest Pitches</a>
#         </div>
#         <div class="menu">
#           <a href="#">Swing & Misses</a>
#         </div>
#       -->
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </nav>
# </div>
# <div id="player_search_container"></div>
# </header>
# <div id="schedule">
# <div id="ticker"></div>
# <div style="clear: both"></div>
# </div>
# <!-- <div class="banner-ad ad-responsive-slot">
#         <div id="ad-top-320" class="ad-responsive-size" data-thresholds="[1,2]" data-sizes="[[320,50]]"></div>
#         <div id="ad-top-728" class="ad-responsive-size" data-thresholds="[3,4,5]" data-sizes="[[728,90]]"></div>
#     </div>
#     -->
# <!-- main content -->
# <div class="article-template"><script>
#     var data = [{"is_qualified":"1","year":"2022","group_type":"0","entity_name":"Mullins, Cedric","entity_id":"656775","entity_team_name":"Orioles","entity_team_name_alt":"BAL","entity_team_id":"110","grouping_code":"Batter","pos":"8","pos_group":"CF","pa":"215","bip":"157","launch_angle_avg":"19.5","sweet_spot_percent":28,"exit_velocity_max":"108.8","exit_velocity_avg":"88.4","exit_velocity_fbld":"91.1","exit_velocity_gb":"89.4","distance_max":"433","distance_avg":"162","distance_hr_avg":"406","hard_hit_ct":"57","hard_hit_percent":36.3,"hard_hit_per_swing":13.4,"barrel_ct":"11","barrels_per_bip":7,"barrels_per_pa":5.1,"barrels_per_swing":2.6,"ba":0.241,"est_ba":0.247,"slg":0.369,"est_slg":0.408,"woba":0.299,"est_woba":0.313,"wobacon":0.332,"est_wobacon":0.35,"xera":null,"era":null,"ba_minus_est_ba_diff":-0.006000000000000005,"slg_minus_est_slg_diff":-0.03899999999999998,"woba_minus_est_woba_diff":-0.014000000000000012,"wobacon_minus_est_wobacon_diff":-0.01799999999999996,"era_minus_xera_diff":null,"est_wobacon_minus_wobacon_diff":-0.01799999999999996,"est_ba_minus_ba_diff":-0.006000000000000005,"est_woba_minus_woba_diff":-0.014000000000000012,"est_slg_minus_slg_diff":-0.03899999999999998,"href":"<a href=\"/savant-player/656775\">Mullins, Cedric</a>"},{"is_qualified":"1","year":"2022","group_type":"0","entity_name":"Hernández, César","entity_id":"514917","entity_team_name":"Nationals","entity_team_name_alt":"WSH","entity_team_id":"120","grouping_code":"Batter","pos":"4","pos_group":"2B","pa":"214","bip":"158","launch_angle_avg":"9.4","sweet_spot_percent":35.4,"exit_velocity_max":"110.8","exit_velocity_avg":"85.6","exit_velocity_fbld":"89.4","exit_velocity_gb":"83.8","distance_max":"380","distance_avg":"141","distance_hr_avg":null,"hard_hit_ct":"50","hard_hit_percent":31.6,"hard_hit_per_swing":12.8,"barrel_ct":"7","barrels_per_bip":4.4,"barrels_per_pa":3.3,"barrels_per_swing":1.8,"ba":0.281,"est_ba":0.277,"slg":0.357,"est_slg":0.398,"woba":0.307,"est_woba":0.315,"wobacon":0.355,"est_wobacon":0.365,"xera":null,"era":null,"ba_minus_est_ba_diff":0.0040000000000000036,"slg_minus_est_slg_diff":-0.041000000000000036,"woba_minus_est_woba_diff":-0.008000000000000007,"wobacon_minus_est_wobacon_diff":-0.010000000000000009,"era_minus_xera_diff":null,"est_wobacon_minus_wobacon_diff":-0.010000000000000009,"est_ba_minus_ba_diff":0.0040000000000000036,"est_woba_minus_woba_diff":-0.008000000000000007,"est_slg_minus_slg_diff":-0.041000000000000036,"href":"<a href=\"/savant-player/514917\">Hernández, César</a>"},{"is_qualified":"1","year":"2022","group_type":"0","entity_name":"Lindor, Francisco","entity_id":"596019","entity_team_name":"Mets","entity_team_name_alt":"NYM","entity_team_id":"121","grouping_code":"Batter","pos":"6","pos_group":"SS","pa":"213","bip":"145","launch_angle_avg":"13.1","sweet_spot_percent":27.6,"exit_velocity_max":"109.2","exit_velocity_avg":"89.1","exit_velocity_fbld":"93.4","exit_velocity_gb":"86.2","distance_max":"423","distance_avg":"161","distance_hr_avg":"391","hard_hit_ct":"57","hard_hit_percent":39.3,"hard_hit_per_swing":14.3,"barrel_ct":"9","barrels_per_bip":6.2,"barrels_per_pa":4.2,"barrels_per_swing":2.3,"ba":0.26,"est_ba":0.267,"slg":0.459,"est_slg":0.458,"woba":0.354,"est_woba":0.353,"wobacon":0.388,"est_wobacon":0.385,"xera":null,"era":null,"ba_minus_est_ba_diff":-0.007000000000000006,"slg_minus_est_slg_diff":0.0010000000000000009,"woba_minus_est_woba_diff":0.0010000000000000009,"wobacon_minus_est_wobacon_diff":0.0030000000000000027,"era_minus_xera_diff":null,"est_wobacon_minus_wobacon_diff":0.0030000000000000027,"est_ba_minus_ba_diff":-0.007000000000000006,"est_woba_minus_woba_diff":0.0010000000000000009,"est_slg_minus_slg_diff":0.0010000000000000009,"href":"<a href=\"/savant-player/596019\">Lindor, Francisco</a>"},{"is_qualified":"1","year":"2022","group_type":"0","entity_name":"France, Ty","entity_id":"664034","entity_team_name":"Mariners","entity_team_name_alt":"SEA","entity_team_id":"136","grouping_code ...
#     var query_string = {"type":"batter","year":"2022","position":"","team":"","min":"q","sort":"1","sortDir":"desc"};
#     var league = [{"is_qualified":"0","year":"2022","group_type":"3","entity_name":"MLB","entity_id":"999999","entity_team_name":"MLB","entity_team_name_alt":"MLB","entity_team_id":null,"grouping_code":"MLB","pos":null,"pos_group":null,"pa":"51760","bip":"35243","launch_angle_avg":"12.6","sweet_spot_percent":33.4,"exit_velocity_max":"119.8","exit_velocity_avg":"88.8","exit_velocity_fbld":"92.9","exit_velocity_gb":"85.9","distance_max":"472","distance_avg":"162","distance_hr_avg":"399","hard_hit_ct":"13710","hard_hit_percent":38.9,"hard_hit_per_swing":14.3,"barrel_ct":"2730","barrels_per_bip":7.7,"barrels_per_pa":5.3,"barrels_per_swing":2.8,"ba":0.239,"est_ba":0.255,"slg":0.384,"est_slg":0.437,"woba":0.308,"est_woba":0.329,"wobacon":0.357,"est_wobacon":0.388,"xera":null,"era":null,"ba_minus_est_ba_diff":-0.016000000000000014,"slg_minus_est_slg_diff":-0.05299999999999999,"woba_minus_est_woba_diff":-0.02100000000000002,"wobacon_minus_est_wobacon_diff":-0.031000000000000028,"era_minus_xera_diff":null,"name":"MLB Average","est_wobacon_minus_wobacon_diff":-0.031000000000000028,"est_ba_minus_ba_diff":-0.016000000000000014,"est_woba_minus_woba_diff":-0.02100000000000002,"est_slg_minus_slg_diff":-0.05299999999999999}];
# </script>
# <style>
#     table th,
#     tbody tr,
#     tbody td {
#         font-family: "Roboto Condensed";
#         font-size: 14px;
#     }
#     .tr-data {
#         font-family: "Roboto Condensed";
#         font-size: 14px;
#         text-align: center;
#     }
#     .align-left {
#         text-align: left;
#     }
# </style>
# <div class="template__content template--one-column__content--one">
# <section class="top-of-page">
# <div id="nav-dropdown" style="position: relative; width: 100%;">
# <div class="leaderboard-title">
# <div style="display: inline-block;">
# <img src="/site-core/images/statcast-logo-gcp-light.png" style="width: 10rem;"/>
# </div>
# <div style="display: inline-block; border-right: solid 2px #c2c2c2;">
#
#     </div>
# <div style="display: inline-block; margin-left: .5rem; padding-top: .25rem;">
# <div class="leaderboard-title-placement">
# <h1 class="leaderboad-nav-title">
#
#
#
#         Expected Statistics
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Leaderboard</h1></div>
# </div>
# </div>
# <div class="leaderboard-dropdown">
# <div class="dropdown">
# <div class="ddl-label" id="lblLeaderboardType">
#         Current:
#
#
#         Expected Statistics
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       </div>
# <div class="dropdown-arrow">▾</div>
# <select id="ddlLeaderboardType">
# <option value="top_performers">Top Performers</option>
# <option value="custom">Custom Leaderboards</option>
# <option value="park_factors">Park Factors</option>
# <optgroup label="-- Hitting">
# <option value="hitting">Exit Velocity &amp; Barrels</option>
# <option selected="" value="expected">Expected Statistics</option>
# <option value="rolling">Rolling Windows</option>
# <option value="swing_take">Swing &amp; Take</option>
# <option value="percentile_rankings">Percentile Rankings</option>
# <option value="batter_pitch_arsenal_stats">Pitch Arsenal Stats</option>
# <option value="home_runs">Home Runs</option>
# <option value="year_to_year">Year to Year Changes</option>
# <option value="pitch_tempo_batter">Pitch Tempo</option>
# </optgroup>
# <optgroup label="-- Pitching">
# <option value="pitching">Exit Velocity &amp; Barrels</option>
# <option value="pitching_expected">Expected Statistics</option>
# <option value="pitch_arsenals">Pitch Arsenals</option>
# <option value="pitch_arsenal_stats">Pitch Arsenal Stats</option>
# <option value="pitch_movement">Pitch Movement</option>
# <option value="active_spin">Active Spin</option>
# <option value="pitching_swing_take">Swing &amp; Take</option>
# <option value="pitching_percentile_rankings">Percentile Rankings</option>
# <option value="pitching_home_runs">Home Runs</option>
# <option value="pitching_year_to_year">Year to Year Changes</option>
# <option value="pitch_tempo">Pitch Tempo</option>
# <option value="spin_direction_compare">Spin Direction - Comparison</option>
# <option value="spin_direction_pitches">Spin Direction - Pitches</option>
# </optgroup>
# <optgroup label="-- Fielding">
# <option value="oaa">Outs Above Average</option>
# <option value="direct_oaa">Outfield Directional OAA</option>
# <option value="catch-prob">Outfield Catch Probability</option>
# <option value="jump">Outfielder Jump</option>
# <option value="poptime">Poptime</option>
# <option value="catcher-framing">Catcher Framing</option>
# </optgroup>
# <optgroup label="-- Running">
# <option value="sprint-speed">Sprint Speed </option>
# <option value="running-splits">90ft Running Splits </option>
# </optgroup>
# <optgroup label="-- Positioning">
# <option value="fielding-situational">Fielder - Situational</option>
# <option value="fielding-situational-all">Fielder - All</option>
# <option value="team-positioning">Team Positioning</option>
# <option value="batter-positioning">Batter Positioning</option>
# <option value="pitcher-positioning">Pitcher Positioning</option>
# </optgroup>
# </select>
# </div>
# </div>
# <div style="clear: both;"></div>
# </div>
# <br/>
# <div class="alert alert-success alert-override">
#             Expected Outcome stats help to remove defense and ballpark from the
#             equation to express the skill shown at the moment of batted ball
#             contact. By looking at the exit velocity and launch angle of each
#             batted ball, a
#             <a href="http://m.mlb.com/glossary/statcast/hit-probability">Hit Probability</a>
#             is assigned based on the outcomes of comparable historic balls in
#             play. By accumulating the expected outcomes of each batted ball with
#             actual strikeouts, walks and hit by pitches,
#             <a href="http://m.mlb.com/glossary/statcast/expected-batting-average">Expected Batting Average (xBA)</a>,
#             <a href="http://m.mlb.com/glossary/statcast/expected-slugging-percentage">Expected Slugging (xSLG)</a>, and (most importantly)
#             <a href="http://m.mlb.com/glossary/statcast/expected-woba">Expected Weighted On-Base Average (xwOBA)</a>
#             tell the story of a player's season based on quality of and amount
#             of contact, not outcomes.
#             <br/>
#             * Qualifiers: 2.1 PA per team game for batters, 1.25 PA per team
#             game for pitchers.
#         </div>
# <div id="leaderboard">
# <form class="form-inline">
# <div class="form-group">
# <div class="dropdown">
# <div class="ddl-label" id="lblType">Batters</div>
# <div class="dropdown-arrow">▾</div>
# <select class="form-control dropdown-fix" id="ddlType">
# <option value="batter">Batters</option>
# <option value="pitcher">Pitchers</option>
# <option value="batter-team">Batters - Team</option>
# <option value="pitcher-team">Pitcher - Team</option>
# </select>
# </div>
# </div>
# <div class="form-group" id="positionGroup" style="display: none">
# <div class="dropdown">
# <div class="ddl-label" id="lblPosition">Position</div>
# <div class="dropdown-arrow">▾</div>
# <select class="form-control dropdown-fix" id="ddlPosition">
# <option selected="" value="">All</option>
# <option value="2">C</option>
# <option value="3">1B</option>
# <option value="4">2B</option>
# <option value="6">SS</option>
# <option value="5">3B</option>
# <option value="7">LF</option>
# <option value="8">CF</option>
# <option value="9">RF</option>
# <option value="10">DH</option>
# </select>
# </div>
# </div>
# <div class="form-group">
# <div class="dropdown">
# <div class="ddl-label" id="lblTeam">Team</div>
# <div class="dropdown-arrow">▾</div>
# <select class="form-control dropdown-fix" id="ddlTeam" name="ddlTeam">
# <option value=""></option>
# <option value="108">Angels</option>
# <option value="117">Astros</option>
# <option value="133">Athletics</option>
# <option value="141">Blue Jays</option>
# <option value="144">Braves</option>
# <option value="158">Brewers</option>
# <option value="138">Cardinals</option>
# <option value="112">Cubs</option>
# <option value="109">D-backs</option>
# <option value="119">Dodgers</option>
# <option value="137">Giants</option>
# <option value="114">Guardians</option>
# <option value="136">Mariners</option>
# <option value="146">Marlins</option>
# <option value="121">Mets</option>
# <option value="120">Nationals</option>
# <option value="110">Orioles</option>
# <option value="135">Padres</option>
# <option value="143">Phillies</option>
# <option value="134">Pirates</option>
# <option value="140">Rangers</option>
# <option value="139">Rays</option>
# <option value="113">Reds</option>
# <option value="111">Red Sox</option>
# <option value="115">Rockies</option>
# <option value="118">Royals</option>
# <option value="116">Tigers</option>
# <option value="142">Twins</option>
# <option value="145">White Sox</option>
# <option value="147">Yankees</option>
# </select>
# </div>
# </div>
# <div class="form-group">
# <div class="dropdown">
# <span class="ddl-label" id="lblSeason">2022</span>
# <div class="dropdown-arrow">▾</div>
# <select class="form-control dropdown-fix" id="ddlSeason">
# <option selected="" value="2022">2022</option>
# <option value="2021">2021</option>
# <option value="2020">2020</option>
# <option value="2019">2019</option>
# <option value="2018">2018</option>
# <option value="2017">2017</option>
# <option value="2016">2016</option>
# <option value="2015">2015</option>
# </select>
# </div>
# </div>
# <div class="form-group" id="team-ddl">
# <div class="dropdown">
# <div class="ddl-label" id="lblMin">
#                             Minimum BIP (Qualified)
#                         </div>
# <div class="dropdown-arrow">▾</div>
# <select class="form-control dropdown-fix" id="ddlMin">
# <option selected="" value="q">Qualified</option>
# <option value="1">1</option>
# <option value="25">25</option>
# <option value="50">50</option>
# <option value="100">100</option>
# <option value="150">150</option>
# <option value="200">200</option>
# <option value="250">250</option>
# <option value="350">350</option>
# <option value="450">450</option>
# <option value="500">500</option>
# <option value="600">600</option>
# </select>
# </div>
# </div>
# <div class="form-group">
# <button class="btn btn-default" id="btnUpdate">
#                         Update
#                     </button>
# </div>
# <div class="form-group">
# <button class="btn btn-default" id="btnCSV">
#                         Download CSV
#                     </button>
# </div>
# </form>
# </div>
# </section>
# <div class="table-savant" id="league_average" style="font-size: 12px"></div>
# <br/><br/>
# <div class="table-savant" id="expected_stats" style="font-size: 12px"></div>
# </div>
# <input id="sort" type="hidden" value="12"/> <input id="sortDir" type="hidden" value="desc"/>
# </div>
# <!-- footer -->
# <footer id="footer">
# <div class="footer-bar-top">
# <div id="footer-container">
# <h6 class="footer-statcast-header" style="padding-left: 1rem">
# <a href="http://m.mlb.com/glossary/statcast" target="_blank">
#                     Statcast Glossary
#                 </a>
# </h6>
# <div style="display: flex; flex-wrap: wrap">
# <div class="footer-flex-container">
# <div class="footer-glossary-title">
# <a href="http://m.mlb.com/glossary/statcast/exit-velocity" target="_blank">
#                             Exit Velocity (EV)
#                         </a>
# </div>
# <div class="footer-glossary-text">
#                         How fast, in miles per hour, a ball was hit by a batter.
#                     </div>
# </div>
# <div class="footer-flex-container">
# <div class="footer-glossary-title">
# <a href="http://m.mlb.com/glossary/statcast/launch-angle">
#                             Launch Angle (LA)
#                         </a>
# </div>
# <div class="footer-glossary-text">
#                         How high/low, in degrees, a ball was hit by a batter.
#                     </div>
# </div>
# <div class="footer-flex-container">
# <div class="footer-glossary-title">
# <a href="http://m.mlb.com/glossary/statcast/barrel">
#                             Barrels
#                         </a>
# </div>
# <div class="footer-glossary-text">
#                         A batted ball with the perfect combination of exit
#                         velocity and launch angle
#                     </div>
# </div>
# <div class="footer-flex-container">
# <div class="footer-glossary-title">
# <a href="http://m.mlb.com/glossary/statcast/hard-hit-rate" target="_blank">
#                             Hard Hit
#                         </a>
# </div>
# <div class="footer-glossary-text">
#                         Statcast defines a 'hard-hit ball' as one hit with an
#                         exit velocity of 95 mph or higher.
#                     </div>
# </div>
# <div class="footer-flex-container">
# <div class="footer-glossary-title">
# <a href="http://m.mlb.com/glossary/statcast/sweet-spot" target="_blank">
#                             Sweet Spot
#                         </a>
# </div>
# <div class="footer-glossary-text">
#                         a batted-ball event with a launch angle between eight
#                         and 32 degrees.
#                     </div>
# </div>
# <div class="footer-flex-container">
# <div class="footer-glossary-title">
# <a href="http://m.mlb.com/glossary/statcast/batted-ball-event" target="_blank">
#                             Batted Ball Event (BBE)
#                         </a>
# </div>
# <div class="footer-glossary-text">
#                         A Batted Ball Event represents any batted ball that
#                         produces a result.
#                     </div>
# </div>
# <div class="footer-flex-container">
# <div class="footer-glossary-title">
# <a href="http://m.mlb.com/glossary/statcast/velocity" target="_blank">
#                             Pitch Velocity
#                         </a>
# </div>
# <div class="footer-glossary-text">
#                         How hard, in miles per hour, a pitch is thrown.
#                     </div>
# </div>
# <div class="footer-flex-container">
# <div class="footer-glossary-title">
# <a href="http://m.mlb.com/glossary/statcast/pitch-movement" target="_blank">
#                             Pitch Movement
#                         </a>
# </div>
# <div class="footer-glossary-text">
#                         The movement of a pitch is defined in inches, both in
#                         raw numbers and as a measurement against average.
#                     </div>
# </div>
# <div class="footer-flex-container">
# <div class="footer-glossary-title">
# <a href="http://m.mlb.com/glossary/statcast/active-spin" target="_blank">
#                             Active Spin
#                         </a>
# </div>
# <div class="footer-glossary-text">
#                         Statcast refers to the spin that contributes to movement
#                         as Active Spin.
#                     </div>
# </div>
# <div class="footer-flex-container">
# <div class="footer-glossary-title">
# <a href="http://m.mlb.com/glossary/statcast/spin-rate" target="_blank">
#                             Spin Rate
#                         </a>
# </div>
# <div class="footer-glossary-text">
#                         How much spin, in revolutions per minute, a pitch was
#                         thrown with.
#                     </div>
# </div>
# <div class="footer-flex-container">
# <div class="footer-glossary-title">
# <a href="http://m.mlb.com/glossary/statcast/extension" target="_blank">
#                             Extension
#                         </a>
# </div>
# <div class="footer-glossary-text">
#                         How far off the mound, in feet, a pitcher releases the
#                         pitch.
#                     </div>
# </div>
# <div class="footer-flex-container">
# <div class="footer-glossary-title">
# <a href="http://m.mlb.com/glossary/statcast/pop-time" target="_blank">
#                             Pop Time
#                         </a>
# </div>
# <div class="footer-glossary-text">
#                         How quickly, in seconds, a catcher can get the ball out
#                         of his glove and to the base on a stolen base or pickoff
#                         attempt.
#                     </div>
# </div>
# <div class="footer-flex-container">
# <div class="footer-glossary-title">
# <a href="http://m.mlb.com/glossary/statcast/arm-strength">
#                             Arm Strength
#                         </a>
# </div>
# <div class="footer-glossary-text">
#                         How hard, in miles per hour, a fielder throws the ball.
#                     </div>
# </div>
# <div class="footer-flex-container">
# <div class="footer-glossary-title">Base-to-base Time</div>
# <div class="footer-glossary-text">
#                         How much time, in seconds, it takes a runner to get from
#                         one base to another, like Home To First.
#                     </div>
# </div>
# <div class="footer-flex-container">
# <div class="footer-glossary-title">
# <a href="http://m.mlb.com/glossary/statcast/distance-covered">
#                             Distance Covered
#                         </a>
# </div>
# <div class="footer-glossary-text">
#                         How far, in feet, a fielder or runner has traveled on a
#                         play.
#                     </div>
# </div>
# <div class="footer-flex-container">
# <div class="footer-glossary-title">
# <a href="http://m.mlb.com/glossary/statcast/lead-distance" target="_blank">
#                             Lead Distance
#                         </a>
# </div>
# <div class="footer-glossary-text">
#                         How far, in feet, a runner is ranging off the bag at the
#                         time of a pitcher's first movement or pitch release.
#                     </div>
# </div>
# <div class="footer-flex-container">
# <div class="footer-glossary-title">
# <a href="http://m.mlb.com/glossary/statcast/jump" target="_blank">
#                             Jump
#                         </a>
# </div>
# <div class="footer-glossary-text">
#                         Jump is a Statcast metric that shows which players have
#                         the fastest reactions and most direct routes in the
#                         outfield.
#                     </div>
# </div>
# <div class="footer-flex-container">
# <div class="footer-glossary-title">
# <a href="http://m.mlb.com/glossary/statcast/outs-above-average" target="_blank">
#                             Outs Above Average (OAA)
#                         </a>
# </div>
# <div class="footer-glossary-text">
#                         A range-based metric of skill that shows how many outs a
#                         player has saved over his peers.
#                     </div>
# </div>
# <div class="footer-flex-container">
# <div class="footer-glossary-title">
# <a href="http://m.mlb.com/glossary/statcast/catch-probability" target="_blank">
#                             Catch Probability
#                         </a>
# </div>
# <div class="footer-glossary-text">
#                         The likelihood, in percent, that an outfielder will be
#                         able to make a catch on an individual batted ball.
#                     </div>
# </div>
# <div class="footer-flex-container">
# <div class="footer-glossary-title">
# <a href="http://m.mlb.com/glossary/statcast/expected-batting-average" target="_blank">
#                             Expected Batting Average (xBA)
#                         </a>
# </div>
# <div class="footer-glossary-text">
#                         xBA measures the likelihood that a batted ball will
#                         become a hit.
#                     </div>
# </div>
# <div class="footer-flex-container">
# <div class="footer-glossary-title">
# <a href="http://m.mlb.com/glossary/statcast/expected-woba" target="_blank">
#                             Expected Weighted On-base Average (xwOBA)
#                         </a>
# </div>
# <div class="footer-glossary-text">
#                         xwOBA is formulated using exit velocity, launch angle
#                         and, on certain types of batted balls, Sprint Speed.
#                     </div>
# </div>
# <div class="footer-flex-container">
# <div class="footer-glossary-title">
# <a href="http://m.mlb.com/glossary/statcast/expected-era" target="_blank">
#                             Expected Earned Run Avg (xERA)
#                         </a>
# </div>
# <div class="footer-glossary-text">
#                         xERA is a simple 1:1 translation of xwOBA, converted to
#                         the ERA scale
#                     </div>
# </div>
# <div class="footer-flex-container">
# <div class="footer-glossary-title">
# <a href="http://m.mlb.com/glossary/statcast/sprint-speed" target="_blank">
#                             Sprint Speed
#                         </a>
# </div>
# <div class="footer-glossary-text">
#                         A measurement of a player's top running speed, expressed
#                         in "feet per second in a player's fastest one-second
#                         window."
#                     </div>
# </div>
# <div class="footer-flex-container">
# <div class="footer-glossary-title">
# <a href="http://m.mlb.com/glossary/statcast/bolt" target="_blank">
#                             Bolt
#                         </a>
# </div>
# <div class="footer-glossary-text">
#                         A Bolt is any run where the Sprint Speed (defined as
#                         "feet per second in a player's fastest one-second
#                         window") of the runner is at least 30 ft/sec.
#                     </div>
# </div>
# </div>
# </div>
# <div class="footer-top">
# <div id="footer-bar">
# <div style="float: left; width: 48%">
# <div style="text-align: right; width: 100%">
# <img class="mlb-logo" src="/site-core/images/savant-logo.svg"/>
# </div>
# </div>
# <div class="logo" style="width: 50%; float: left; text-align: left">
# <a href="/">
# <span class="primary-color">savant</span>
# </a>
# </div>
# </div>
# </div>
# <ul id="footer-links">
# <li>
# <a class="footer-tou" href="https://www.mlb.com/official-information/terms-of-use">
#                     Terms of Use
#                 </a>
# </li>
# <li>
# <a class="footer-privacy" href="https://www.mlb.com/official-information/privacy-policy">
#                     Privacy Policy
#                 </a>
# </li>
# <li>
# <a class="footer-notices" href="https://www.mlb.com/official-information/legal-notices">
#                     Legal Notices
#                 </a>
# </li>
# <li>
# <a class="footer-notices" data-phone-href="https://www.mlb.com" href="https://www.mlb.com">
#                     MLB.com
#                 </a>
# </li>
# </ul>
# <div id="copyright-container">
#             © MLB Advanced Media, LP. All rights reserved.
#         </div>
# </div>
# </footer>
# <!-- core javascript files -->
# <script>
#     var s_account = "basesitedesktopprod,basesiteglobalprod";
# </script>
# <script src="/builds/site-core/94169dc350891bf0b17186bf1435668a3f6dd75b_1653579298/scripts/site-core.js" type="text/javascript"></script>
# <!-- build scripts -->
# <script type="text/javascript">
#
#     (function() {
#
#         var siteJS = {"desktop":"site.bundle","tablet":"site.bundle","phone":"site.bundle"};
#         var sectionJS = {"desktop":"build/section.bundle","tablet":"build/section.bundle","phone":"build/section.bundle"};
#         var pageJS = {"desktop":"build/expected-stats.bundle","tablet":"build/expected-stats.bundle","phone":"build/expected-stats.bundle"};
#         var type = getStartupDeviceTypeString();
#
#
#         /* site and section build=true */
#
#             var siteScripts = [];
#             var scripts = [];
#
#             if (siteJS[type]) {
#                 siteScripts.push('/builds/site-core/94169dc350891bf0b17186bf1435668a3f6dd75b_1653579298/scripts/'+siteJS[type]+'.js');
#             }
#
#             if (sectionJS[type]) {
#                 scripts.push('/sections/leaderboard/builds/82bacc061e2cf7289fbd6c5a71b14eb79cd922a8/scripts/'+sectionJS[type]+'.js');
#             }
#             if (pageJS[type]) {
#                 scripts.push('/sections/leaderboard/builds/82bacc061e2cf7289fbd6c5a71b14eb79cd922a8/scripts/'+pageJS[type]+'.js');
#             }
#             if (siteScripts.length) {
#                 requirejs.config({
#                     waitSeconds: 18,
#                     paths : {
#                         "bam-video-bootstrap": "/video/videocore/video"
#                     }
#                 });
#
#                 requirejs(siteScripts, function(){
#                     if (scripts.length) {
#                         requirejs(scripts);
#                     }
#                 });
#             }
#
#
#     })();
# </script>
# <!-- analytics -->
# <script type="text/javascript">
#             var s_account = "mlbglobal08,mlbcom08";
#             </script>
# <script src="https://securea.mlb.com/scripts/mlbamscv2.js" type="text/javascript"></script>
# <script type="text/javascript">
#             s.pageName = "Baseballsavant.com Site: Statcast Expected wOBA, xBA, xSLG"
#             s.channel = "Baseballsavant.com Site";
#             s.prop1 = "Baseballsavant.com Site";
#             s.prop24 = s_account;
#
#             s.events = "event4";
#
#             s.campaign = s.getQueryParam("partnerId");
#             s.eVar1 = s.getQueryParam("vbID");
#             s.eVar4 = s.getQueryParam("affiliateId");
#             s.eVar14 = s.getQueryParam("tcid");
#             s.eVar21 = s.getQueryParam("tdl");
#             s.eVar22 = s.getQueryParam("tfl");
#             s.eVar25 = s.getQueryParam("mlbkw");
#
#
#             s.linkInternalFilters="javascript:,mlb.com,localhost,ticketreturn.com,ticketmaster.com,tickets.com,glitnirticketing.com,etix.com,streamlineticketing.com,baseballsavant.com";
#
#             /********* DO NOT ALTER ANYTHING BELOW THIS LINE ! **************/
#             var s_code=s.t();if(s_code)document.write(s_code)//--></script>
# <script type="text/javascript"><!--
#             if(navigator.appVersion.indexOf('MSIE')>=0)document.write(unescape('%3C')+'\!-'+'-')
#             //--></script><noscript><a href="http://www.omniture.com" title="Web Analytics"><img alt="" border="0" height="1" src="http://mlbglobal08.112.2O7.net/b/ss/mlbglobal08/1/H.13--NS/0?[AQB]&amp;cdp=3&amp;[AQE]" width="1"/></a></noscript><!--/DO NOT REMOVE/-->
# <!-- End SiteCatalyst code version: H.23.8 -->
# <script>
#             window.applicationEnvironment = 'production'
#             window.baseDeploy = '94169dc350891bf0b17186bf1435668a3f6dd75b_1653579298'
#         </script>
# <!-- TODO debugging -->
# </body>

# %%
# stuff[3]

# %% [markdown]
# # Extra

# %%
# pp_xba['Team'][0] = pp_xba['team'][1]
# pp_xba['Team'][1] = pp_xba['team'][0]
# pp_xba['Team'][2] = pp_xba['team'][3]
# pp_xba['Team'][3] = pp_xba['team'][2]
# pp_xba['Team'][4] = pp_xba['team'][5]
# pp_xba['Team'][5] = pp_xba['team'][4]
# pp_xba['Team'][6] = pp_xba['team'][7]
# pp_xba['Team'][7] = pp_xba['team'][6]
# pp_xba['Team'][8] = pp_xba['team'][9]
# pp_xba['Team'][9] = pp_xba['team'][8]
# pp_xba['Team'][10] = pp_xba['team'][11]
# pp_xba['Team'][11] = pp_xba['team'][10]
# pp_xba['Team'][12] = pp_xba['team'][13]
# pp_xba['Team'][13] = pp_xba['team'][12]
# pp_xba['Team'][14] = pp_xba['team'][15]
# pp_xba['Team'][15] = pp_xba['team'][14]
# pp_xba['Team'][16] = pp_xba['team'][17]
# pp_xba['Team'][17] = pp_xba['team'][16]
# pp_xba['Team'][18] = pp_xba['team'][19]
# pp_xba['Team'][19] = pp_xba['team'][18]
# pp_xba['Team'][20] = pp_xba['team'][21]
# pp_xba['Team'][21] = pp_xba['team'][20]
# pp_xba['Team'][22] = pp_xba['team'][23]
# pp_xba['Team'][23] = pp_xba['team'][22]
# pp_xba['Team'][24] = pp_xba['team'][25]
# pp_xba['Team'][25] = pp_xba['team'][24]
# pp_xba['Team'][26] = pp_xba['team'][27]
# pp_xba['Team'][27] = pp_xba['team'][26]
# pp_xba['Team'][28] = pp_xba['team'][29]
# pp_xba['Team'][29] = pp_xba['team'][28]
# pp_xba['Team'][30] = pp_xba['team'][31]
# pp_xba['Team'][31] = pp_xba['team'][30]
# pp_xba['Team'][32] = pp_xba['team'][33]
# pp_xba['Team'][33] = pp_xba['team'][32]
# pp_xba['Team'][34] = pp_xba['team'][35]
# pp_xba['Team'][35] = pp_xba['team'][34]
